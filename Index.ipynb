# %% [markdown]
# My Coursera_Capstone

# %% [markdown]
# To do:
#
# 1_Import the pandas library as pd.
# 2_Import the Numpy library as np.
# 3_Print the following the statement: Hello Capstone Project Course!

# %%
#import libraries
import pandas as pd
import numpy as np

# %%
#print Hello Capstone Project Course!

print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
